# %% [markdown]
# # HW1: Introduction to RL
# > - Full Name: **[Mohammad Javad Amin]**
# > - Student ID: **[Stundet ID]**
#
#
# This notebook is designed for is designed to provide hands-on experience with RL modeling, algorithm implementation, and performance evaluation. Students will explore RL concepts through predefined environments and custom-designed settings.
#
# Follow the instructions in each section to complete the homework.

# %% [markdown]
# ## Setup Instructions
# Seting up RL dependecies for first time may be challenging. Some  torch or gymnasium (Sklearn lib in SL world!) environments need additional set up on your system. If you encountered error and failure after hours of search and try, feel free to be in contact with TA's.  Run the following commands to install dependencies before starting the notebook:

# %%
# !apt-get install x11-utils > /dev/null 2>&1
# !pip install pyglet > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl > /dev/null 2>&1
# !apt-get install xvfb
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libxfont2 x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils xserver-common
# The following NEW packages will be installed:
#   libxfont2 x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils xserver-common xvfb
# 0 upgraded, 7 newly installed, 0 to remove and 20 not upgraded.
# Need to get 7,728 kB of archives.
# After this operation, 11.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.12 [28.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.12 [864 kB]
# Fetched 7,728 kB in 0s (16.2 MB/s)
# Selecting previously unselected package libxfont2:amd64.
# (Reading database ... 124995 files and directories currently installed.)
# Preparing to unpack .../0-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../1-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../2-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../3-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../4-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../5-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.12_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../6-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.12_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up xfonts-base (1:1.0.5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
# !pip install pyvirtualdisplay > /dev/null 2>&1
# !pip install swig
# !pip install stable-baselines3 "gymnasium[all]" pygame matplotlib numpy pandas
# Out:
# Collecting swig
#   Downloading swig-4.3.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (3.5 kB)
# Downloading swig-4.3.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 13.1 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.3.0
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pygame in /usr/local/lib/python3.11/dist-packages (2.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: gymnasium[all] in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.5.1+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (0.0.4)
# Requirement already satisfied: ale-py>=0.9 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (0.10.1)
# Collecting box2d-py==2.3.5 (from gymnasium[all])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (4.3.0)
# Collecting mujoco-py<2.2,>=2.1 (from gymnasium[all])
#   Downloading mujoco_py-2.1.2.14-py3-none-any.whl.metadata (669 bytes)
# Collecting cython<3 (from gymnasium[all])
#   Downloading Cython-0.29.37-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (3.1 kB)
# Collecting mujoco>=2.1.5 (from gymnasium[all])
#   Downloading mujoco-3.2.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: imageio>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (2.37.0)
# Requirement already satisfied: jax>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (0.4.33)
# Requirement already satisfied: jaxlib>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (0.4.33)
# Requirement already satisfied: flax>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (0.10.3)
# Requirement already satisfied: opencv-python>=3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (4.11.0.86)
# Requirement already satisfied: moviepy>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (1.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (1.1.0)
# Requirement already satisfied: optax in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (0.2.4)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (0.6.4)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (0.1.71)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (13.9.4)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (6.0.2)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (0.1.8)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.0->gymnasium[all]) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.0->gymnasium[all]) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.0->gymnasium[all]) (1.13.1)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.11/dist-packages (from moviepy>=1.0.0->gymnasium[all]) (4.4.2)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from moviepy>=1.0.0->gymnasium[all]) (0.6.0)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.11/dist-packages (from moviepy>=1.0.0->gymnasium[all]) (4.67.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from moviepy>=1.0.0->gymnasium[all]) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.11/dist-packages (from moviepy>=1.0.0->gymnasium[all]) (0.1.10)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.1.5->gymnasium[all]) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.1.5->gymnasium[all]) (1.12.0)
# Collecting glfw (from mujoco>=2.1.5->gymnasium[all])
#   Downloading glfw-2.8.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.1.5->gymnasium[all]) (3.1.9)
# Requirement already satisfied: cffi>=1.10 in /usr/local/lib/python3.11/dist-packages (from mujoco-py<2.2,>=2.1->gymnasium[all]) (1.17.1)
# Collecting fasteners~=0.15 (from mujoco-py<2.2,>=2.1->gymnasium[all])
#   Downloading fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.10->mujoco-py<2.2,>=2.1->gymnasium[all]) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.5.0->gymnasium[all]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.5.0->gymnasium[all]) (2.18.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[all]) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[all]) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.11/dist-packages (from optax->flax>=0.5.0->gymnasium[all]) (0.1.88)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (1.6.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (4.25.6)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (4.11.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex>=0.1.87->optax->flax>=0.5.0->gymnasium[all]) (0.12.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.5.0->gymnasium[all]) (0.1.2)
# Downloading stable_baselines3-2.5.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 9.1 MB/s eta 0:00:00
# Downloading Cython-0.29.37-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 33.3 MB/s eta 0:00:00
# Downloading mujoco-3.2.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 53.9 MB/s eta 0:00:00
# Downloading mujoco_py-2.1.2.14-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 36.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 88.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 68.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.6 MB/s eta 0:00:00
# Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Downloading glfw-2.8.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 14.8 MB/s eta 0:00:00
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp311-cp311-linux_x86_64.whl size=2379445 sha256=3aa8bd450e49253da19a9fd76465038d9e658d60c13d07243ce9d30ecbbb263d
#   Stored in directory: /root/.cache/pip/wheels/ab/f1/0c/d56f4a2bdd12bae0a0693ec33f2f0daadb5eb9753c78fa5308
# Successfully built box2d-py
# Installing collected packages: glfw, box2d-py, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, fasteners, cython, nvidia-cusparse-cu12, nvidia-cudnn-cu12, mujoco-py, nvidia-cusolver-cu12, mujoco, stable-baselines3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.12
#     Uninstalling Cython-3.0.12:
#       Successfully uninstalled Cython-3.0.12
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed box2d-py-2.3.5 cython-0.29.37 fasteners-0.19 glfw-2.8.0 mujoco-3.2.7 mujoco-py-2.1.2.14 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stable-baselines3-2.5.0

# %% [markdown]
# Hamid is EE student who loves learning about RL. He tried to use **Gymnasium** and **Stable-Baselines3** to solve games he played as a kid.
#
# He started to list the games which was provided in gymnasium library.

# %%
from gymnasium import envs

all_envs = envs.registry
env_ids = [env_spec  for env_spec in all_envs]
print("Gymnasium envs listed:",sorted(env_ids))
# Out:
# Gymnasium envs listed: ['Acrobot-v1', 'Ant-v2', 'Ant-v3', 'Ant-v4', 'Ant-v5', 'BipedalWalker-v3', 'BipedalWalkerHardcore-v3', 'Blackjack-v1', 'CarRacing-v3', 'CartPole-v0', 'CartPole-v1', 'CliffWalking-v0', 'FrozenLake-v1', 'FrozenLake8x8-v1', 'GymV21Environment-v0', 'GymV26Environment-v0', 'HalfCheetah-v2', 'HalfCheetah-v3', 'HalfCheetah-v4', 'HalfCheetah-v5', 'Hopper-v2', 'Hopper-v3', 'Hopper-v4', 'Hopper-v5', 'Humanoid-v2', 'Humanoid-v3', 'Humanoid-v4', 'Humanoid-v5', 'HumanoidStandup-v2', 'HumanoidStandup-v4', 'HumanoidStandup-v5', 'InvertedDoublePendulum-v2', 'InvertedDoublePendulum-v4', 'InvertedDoublePendulum-v5', 'InvertedPendulum-v2', 'InvertedPendulum-v4', 'InvertedPendulum-v5', 'LunarLander-v3', 'LunarLanderContinuous-v3', 'MountainCar-v0', 'MountainCarContinuous-v0', 'Pendulum-v1', 'Pusher-v2', 'Pusher-v4', 'Pusher-v5', 'Reacher-v2', 'Reacher-v4', 'Reacher-v5', 'Swimmer-v2', 'Swimmer-v3', 'Swimmer-v4', 'Swimmer-v5', 'Taxi-v3', 'Walker2d-v2', 'Walker2d-v3', 'Walker2d-v4', 'Walker2d-v5', 'phys2d/CartPole-v0', 'phys2d/CartPole-v1', 'phys2d/Pendulum-v0', 'tabular/Blackjack-v0', 'tabular/CliffWalking-v0']

# %% [markdown]
# Then He selected Mountain Car Game to work with:

# %%
import gymnasium as gym
env = gym.make("MountainCar-v0", render_mode="rgb_array", goal_velocity=0.1)

print("Action Space {}".format(env.action_space))
print("State Space {}".format(env.observation_space))

print("Action Example: {}".format(env.action_space.sample()))
print("State Example: {}".format(env.observation_space.sample()))
# Out:
# Action Space Discrete(3)
# State Space Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Example: 2
# State Example: [0.5794639  0.06534208]

# %% [markdown]
# Hamid wanted to visualize the env for better understandig of gym envs. He had two options:
#
#
# 1.   rendering inside the colab
# 2.   rendering as video file

# %% [markdown]
# For ploting the game **inside** the colab he used **pyvirtualdisplay** package:

# %%
from pyvirtualdisplay import Display
import numpy as np
import matplotlib.pyplot as plt
from IPython import display as ipythondisplay

display = Display(visible=0, size=(400, 300))
display.start()

# %% [markdown]
# So He started modify the code to learn how action works and plot it. He selected action of
#
#  *`2: Accelerate to the right`*
#
# For every state of car.

# %%
env.reset()
prev_screen = env.render( )
plt.imshow(prev_screen)

for i in range(40):
  # action = env.action_space.sample()  # Random action
  action = 1 # Action Hamid modified to practice
  obs, reward,terminated, truncated, info = env.step(action)
  screen = env.render()

  plt.imshow(screen)
  ipythondisplay.clear_output(wait=True)
  ipythondisplay.display(plt.gcf())

  if terminated:
    break

ipythondisplay.clear_output(wait=True)
env.close()

# %% [markdown]
# But for saving game as **video** he defined a function (it's okay if you don't understand just try to run the code and see the output, then try to modify envs!):

# %%
import logging
from gymnasium.wrappers import RecordEpisodeStatistics, RecordVideo

training_period = 250  # record the agent's episode every 250
num_training_episodes = 1000  # total number of training episodes

env = gym.make("MountainCar-v0", render_mode="rgb_array")
env = RecordVideo(env, video_folder="MountainCar-v0-agent", name_prefix="training",
                  episode_trigger=lambda x: x % training_period == 0)
env = RecordEpisodeStatistics(env)

for episode_num in range(num_training_episodes):
    obs, info = env.reset()

    episode_over = False
    while not episode_over:
        action = env.action_space.sample()  # replace with actual agent
        obs, reward, terminated, truncated, info = env.step(action)

        episode_over = terminated or truncated

    logging.info(f"episode-{episode_num}", info["episode"])
env.close()

# %% [markdown]
# The videos are in MountainCar-v0-agent folder of your colab folder.

# %% [markdown]
# But the car couldn't reach the goal state on top of the right hill. So he tried to implement RL algorithm for learning it

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# Parallel environments can bet set but Hamid set 1 env
vec_env = make_vec_env("MountainCar-v0", n_envs=1)

model = PPO("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=25000)
model.save("ppo_MountainCar")

del model # remove to demonstrate saving and loading

# %% [markdown]
# **Loading saved model**
#
# After training model using PPO and saving it, Hamid started to load the model with the name he saved in cell above:

# %%
model = PPO.load("ppo_MountainCar")
obs = vec_env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = vec_env.step(action)
    print(obs, rewards, dones, info)
    if dones[0]:
      break
# Out:
# [[-4.8242056e-01 -3.1036141e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-4.8203900e-01  3.8158701e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-4.8196828e-01  7.0695554e-05]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.481209    0.00075928]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.47976682  0.00144221]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4786524   0.00111442]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.47687405  0.00177834]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.474445    0.00242905]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.47138327  0.00306173]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.46871156  0.00267172]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.46544963  0.00326192]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4616216   0.00382801]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.45825577  0.00336585]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.45437685  0.00387891]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.45201337  0.00236347]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.45018268  0.0018307 ]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-4.4989815e-01  2.8452062e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4491619   0.00073626]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.44797927  0.00118261]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.44735897  0.00062032]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.44630548  0.00105349]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4448265   0.00147897]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.44293284  0.00189366]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.44063827  0.00229456]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.43795952  0.00267876]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.43591604  0.0020435 ]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-4.3552259e-01  3.9344167e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.43478206  0.00074053]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-4.3469980e-01  8.2258615e-05]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-4.3427640e-01  4.2339214e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.43351495  0.00076146]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4324209   0.00109403]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.43300223 -0.00058131]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.43525466 -0.00225245]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.43716198 -0.0019073 ]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.43971032 -0.00254834]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.44188118 -0.00217088]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.44365883 -0.00177764]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.44703028 -0.00337146]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.45097098 -0.00394069]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.45445207 -0.00348109]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.45744807 -0.00299598]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.46193692 -0.00448886]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4658856 -0.0039487]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.470265   -0.00437938]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.47404268 -0.00377768]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.47719067 -0.00314799]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4806856  -0.00349492]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.48350146 -0.00281588]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.48561737 -0.00211589]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4890175  -0.00340013]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4936765  -0.00465903]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.49755967 -0.00388314]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5006379  -0.00307824]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5028882  -0.00225031]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5052938  -0.00240554]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5078365  -0.00254276]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.50949746 -0.00166093]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5112641  -0.00176666]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5121232  -0.00085915]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.1206845e-01  5.4803040e-05]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5131001  -0.00103166]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.51421046 -0.00111038]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5163913  -0.00218079]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5176261  -0.00123484]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.51890576 -0.00127963]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.52122056 -0.00231483]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.52255327 -0.00133266]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.52489376 -0.00234051]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.52722454 -0.00233079]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5305281 -0.0033036]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5347798  -0.00425163]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5389476  -0.00416779]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5430003  -0.00405272]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.54590756 -0.00290729]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.54764766 -0.0017401 ]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.54920757 -0.00155989]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.55057555 -0.00136801]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5517415 -0.0011659]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5536966  -0.00195509]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5544262  -0.00072966]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.5392498e-01  5.0121784e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5521966   0.00172835]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.55025405  0.00194257]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5471118   0.00314227]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.54279333  0.00431848]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.53933096  0.00346235]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.53475064  0.0045803 ]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.52908677  0.00566393]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.52438164  0.00470508]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5206707   0.00371096]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5169817  0.003689 ]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.51234233  0.00463937]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.50678736  0.00555496]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.50235844  0.00442893]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.49808872  0.00426974]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4950101  0.0030786]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.49214566  0.00286445]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.48851678  0.0036289 ]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4851505   0.00336627]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.48107195  0.00407854]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4773115   0.00376046]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.47289708  0.00441442]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.46986145  0.00303562]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.46822712  0.00163433]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.46700618  0.00122095]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-4.6720764e-01 -2.0145516e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.46883    -0.00162237]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4718613  -0.00303129]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.47427908 -0.00241777]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4760654  -0.00178632]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.478207   -0.00214161]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.479688 -0.001481]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.48249736 -0.00280938]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.48661423 -0.00411686]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4900079  -0.00339367]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4936531  -0.00364518]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.49852255 -0.00486947]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5025799  -0.00405736]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5057948 -0.0032149]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5091432  -0.00334837]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.51359993 -0.00445675]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5171317  -0.00353173]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5197119  -0.00258023]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5213213  -0.00160938]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.52194774 -0.00062646]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5235866  -0.00163885]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.52422553 -0.00063894]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.2385974e-01  3.6576408e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.52249205  0.00136772]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.2213264e-01  3.5942098e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5207842   0.00134842]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5184569   0.00232732]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5171681   0.00128875]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.169276e-01  2.405262e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5157371  0.0011905]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5146056   0.00113154]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5125415  0.0020641]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5105603   0.00198118]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5086769   0.00188342]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5079053   0.00077154]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.0825143e-01 -3.4611492e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5077126   0.00053882]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5062929   0.00141972]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5040029   0.00228998]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5008598  0.0031431]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.49788713  0.00297269]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.49410707  0.00378004]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.49054793  0.00355914]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.48823628  0.00231167]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.48518932  0.00304695]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.48142982  0.00375951]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.47698572  0.00444409]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.47289008  0.00409563]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4701733   0.00271678]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4678555  0.0023178]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.46495384  0.00290167]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.46248972  0.0024641 ]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4594814   0.00300835]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.45695096  0.00253043]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.45391706  0.00303389]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.45140198  0.00251508]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.44942418  0.00197782]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-4.4899806e-01  4.2609475e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.45012683 -0.00112875]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.45080218 -0.00067534]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.45201916 -0.00121699]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.45276886 -0.00074972]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-4.5304582e-01 -2.7695156e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.45484796 -0.00180216]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4571621  -0.00231414]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.45897123 -0.00180912]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.46026203 -0.0012908 ]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.461025   -0.00076297]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.46225452 -0.00122952]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.46394154 -0.00168701]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4660736  -0.00213206]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.46863496 -0.00256136]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.47260666 -0.00397172]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.47595933 -0.00335267]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4806681  -0.00470875]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.48669794 -0.00602984]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.49200398 -0.00530603]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4985466  -0.00654264]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.50427693 -0.00573035]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.51015216 -0.00587519]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.51512814 -0.00497601]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5201677  -0.00503953]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.525233   -0.00506526]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.53028595 -0.00505301]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5342888  -0.00400286]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.53721154 -0.0029227 ]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.54003215 -0.00282063]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.54172957 -0.00169743]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5422911  -0.00056151]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.54171246  0.0005786 ]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.4199809e-01 -2.8561003e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5431458  -0.00114769]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.54414696 -0.00100117]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.52466506  0.        ]] [-1.] [ True] [{'episode': {'r': -200.0, 'l': 200, 't': 2330.612066}, 'TimeLimit.truncated': True, 'terminal_observation': array([-0.5459941 , -0.00184715], dtype=float32)}]

# %% [markdown]
# # **Task 1: Solving Predefined Environments (45 points)**
# 1.1. Choose two environments from the list which are implemented by  other developers and communities and train RL agents using stable-baselines3. Don't forget to check workshop notebook.
#
# **Environments:**
# - [CartPole](https://gymnasium.farama.org/environments/classic_control/cart_pole/)
# - [FrozenLake](https://gymnasium.farama.org/environments/toy_text/frozen_lake/)
# - [Taxi](https://gymnasium.farama.org/environments/toy_text/taxi/)
# - Flappy Bird (Custom env which you can google it)

# %% [markdown]
# 📊 1.2. Algorithm Comparison:
#
#
#  Compare RL algorithms and results (at least two algorithms e.g., PPO, DQN) based on:
# - Total reward over time
# - Hyperparameters (check the docs)

# %% [markdown]
# Env1 implementation. [ CartPole ]
#
# Action spaces
# * 0: Push cart to the left
# * 1: Push cart to the right

# %%
import gymnasium as gym
from stable_baselines3.common.monitor import Monitor
from stable_baselines3 import DQN, PPO
import pandas as pd
import matplotlib.pyplot as plt

class train_env:
  def __init__(self, Env):
    if Env == "FrozenLake-v1":
        self.env_ppo = Monitor(gym.make(Env, is_slippery=False), filename="ppo_monitor.csv")
        self.env_dqn = Monitor(gym.make(Env, is_slippery=False), filename="dqn_monitor.csv")

    print("Action Space {}".format(self.env_ppo.action_space))
    print("State Space {}".format(self.env_ppo.observation_space))

    self.ppo_hyperparams = {
    "learning_rate": 3e-4,   # default is usually 3e-4 for PPO
    "n_steps": 2048,         # might be large for FrozenLake (small state space), feel free to reduce
    "batch_size": 64,
    "n_epochs": 10,
    "gamma": 0.99,
    "gae_lambda": 0.95,
    "clip_range": 0.2,
    }

# Example hyperparameters for DQN
    self.dqn_hyperparams = {
      "learning_rate": 1e-4,          # default is usually 1e-4 or 1e-3
      "buffer_size": 50_000,          # replay buffer size
      "learning_starts": 1000,        # how many steps of experience before we start training
      "batch_size": 32,
      "tau": 1.0,                     # soft update coefficient
      "gamma": 0.99,
      "exploration_fraction": 0.1,    # fraction of training where exploration rate is annealed
      "exploration_initial_eps": 1.0,
      "exploration_final_eps": 0.05,
    }
  def __create_model(self):
      self.model_ppo = PPO(
        policy="MlpPolicy",
        env=self.env_ppo,
        verbose=1,
        **self.ppo_hyperparams  # unpack PPO hyperparameters
      )
      self.model_dqn = DQN(
        policy="MlpPolicy",
        env=self.env_dqn,
        verbose=1,
        **self.dqn_hyperparams  # unpack DQN hyperparameters

      )
  def __train_models(self):
      self.model_ppo.learn(total_timesteps=50_000)
      self.model_dqn.learn(total_timesteps=50_000)

  def __plot(self):
      df_ppo = pd.read_csv("ppo_monitor.csv", skiprows=1)
      df_dqn = pd.read_csv("dqn_monitor.csv", skiprows=1)

      plt.figure(figsize=(10, 6))
      plt.plot(df_ppo["r"], label="PPO Rewards")
      plt.plot(df_dqn["r"], label="DQN Rewards")
      plt.xlabel("Episode")
      plt.ylabel("Total Reward")
      plt.title("FrozenLake - PPO vs DQN Reward Comparison")
      plt.legend()
      plt.show()

  def run(self,show = True):
      self.__create_model()
      self.__train_models()
      if show:
          self.__plot()


env_lake = train_env("FrozenLake-v1")
env_lake.run(show = True)
# Out:
# Streaming output truncated to the last 5000 lines.
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.94e-05 |
# |    n_updates        | 4775     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 0.03     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4672     |
# |    fps              | 509      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 20119    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.81e-05 |
# |    n_updates        | 4779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4676     |
# |    fps              | 509      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 20143    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00528  |
# |    n_updates        | 4785     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4680     |
# |    fps              | 508      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 20164    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000214 |
# |    n_updates        | 4790     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4684     |
# |    fps              | 508      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 20176    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000604 |
# |    n_updates        | 4793     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4688     |
# |    fps              | 508      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 20188    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.46e-05 |
# |    n_updates        | 4796     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.29     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4692     |
# |    fps              | 508      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 20210    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00419  |
# |    n_updates        | 4802     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.46     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4696     |
# |    fps              | 508      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 20235    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.34e-05 |
# |    n_updates        | 4808     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.63     |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4700     |
# |    fps              | 507      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 20261    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000303 |
# |    n_updates        | 4815     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.53     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4704     |
# |    fps              | 507      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 20290    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.18e-05 |
# |    n_updates        | 4822     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.6      |
# |    ep_rew_mean      | 0.23     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4708     |
# |    fps              | 507      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 20305    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.7e-05  |
# |    n_updates        | 4826     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.73     |
# |    ep_rew_mean      | 0.26     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4712     |
# |    fps              | 506      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 20326    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.5e-06  |
# |    n_updates        | 4831     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.28     |
# |    ep_rew_mean      | 0.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4716     |
# |    fps              | 506      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 20389    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.78e-05 |
# |    n_updates        | 4847     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 0.32     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4720     |
# |    fps              | 505      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 20508    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00211  |
# |    n_updates        | 4876     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.71     |
# |    ep_rew_mean      | 0.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4724     |
# |    fps              | 505      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 20532    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000474 |
# |    n_updates        | 4882     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.71     |
# |    ep_rew_mean      | 0.4      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4728     |
# |    fps              | 505      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 20558    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.17e-06 |
# |    n_updates        | 4889     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.13     |
# |    ep_rew_mean      | 0.43     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4732     |
# |    fps              | 505      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 20608    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.54e-06 |
# |    n_updates        | 4901     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.91     |
# |    ep_rew_mean      | 0.45     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4736     |
# |    fps              | 505      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 20694    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.92e-05 |
# |    n_updates        | 4923     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 0.48     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4740     |
# |    fps              | 505      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 20714    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.29e-05 |
# |    n_updates        | 4928     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 0.52     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4744     |
# |    fps              | 505      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 20738    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.27e-05 |
# |    n_updates        | 4934     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.9      |
# |    ep_rew_mean      | 0.56     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4748     |
# |    fps              | 505      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 20762    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00276  |
# |    n_updates        | 4940     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.75     |
# |    ep_rew_mean      | 0.59     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4752     |
# |    fps              | 505      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 20784    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.16e-05 |
# |    n_updates        | 4945     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.45     |
# |    ep_rew_mean      | 0.63     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4756     |
# |    fps              | 505      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 20810    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.55e-05 |
# |    n_updates        | 4952     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.58     |
# |    ep_rew_mean      | 0.66     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4760     |
# |    fps              | 505      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 20835    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.8e-05  |
# |    n_updates        | 4958     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.99     |
# |    ep_rew_mean      | 0.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4764     |
# |    fps              | 505      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 20888    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000918 |
# |    n_updates        | 4971     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.12     |
# |    ep_rew_mean      | 0.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4768     |
# |    fps              | 505      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 20913    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00226  |
# |    n_updates        | 4978     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.2      |
# |    ep_rew_mean      | 0.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4772     |
# |    fps              | 505      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 20939    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000733 |
# |    n_updates        | 4984     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.2      |
# |    ep_rew_mean      | 0.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4776     |
# |    fps              | 505      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 20963    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.23e-05 |
# |    n_updates        | 4990     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.25     |
# |    ep_rew_mean      | 0.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4780     |
# |    fps              | 505      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 20989    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.66e-05 |
# |    n_updates        | 4997     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.39     |
# |    ep_rew_mean      | 0.79     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4784     |
# |    fps              | 505      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 21015    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3e-06    |
# |    n_updates        | 5003     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.51     |
# |    ep_rew_mean      | 0.83     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4788     |
# |    fps              | 505      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 21039    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.76e-05 |
# |    n_updates        | 5009     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.53     |
# |    ep_rew_mean      | 0.85     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4792     |
# |    fps              | 505      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 21063    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000328 |
# |    n_updates        | 5015     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.86     |
# |    ep_rew_mean      | 0.83     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4796     |
# |    fps              | 505      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 21121    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.83e-05 |
# |    n_updates        | 5030     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 0.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4800     |
# |    fps              | 506      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 21324    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45e-05 |
# |    n_updates        | 5080     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 0.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4804     |
# |    fps              | 507      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 21386    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.1e-06  |
# |    n_updates        | 5096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 0.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4808     |
# |    fps              | 507      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 21442    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000186 |
# |    n_updates        | 5110     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 0.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4812     |
# |    fps              | 507      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 21565    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.2e-05  |
# |    n_updates        | 5141     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4816     |
# |    fps              | 509      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 21777    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.13e-05 |
# |    n_updates        | 5194     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 0.79     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4820     |
# |    fps              | 511      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 22110    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15e-05 |
# |    n_updates        | 5277     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 0.78     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4824     |
# |    fps              | 512      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 22269    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.83e-07 |
# |    n_updates        | 5317     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.4     |
# |    ep_rew_mean      | 0.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4828     |
# |    fps              | 514      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 22496    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000243 |
# |    n_updates        | 5373     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.5     |
# |    ep_rew_mean      | 0.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4832     |
# |    fps              | 514      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 22556    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.21e-06 |
# |    n_updates        | 5388     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19       |
# |    ep_rew_mean      | 0.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4836     |
# |    fps              | 514      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 22598    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.3e-07  |
# |    n_updates        | 5399     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 0.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4840     |
# |    fps              | 516      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 22932    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.42e-05 |
# |    n_updates        | 5482     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 0.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4844     |
# |    fps              | 517      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 23119    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0002   |
# |    n_updates        | 5529     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.3     |
# |    ep_rew_mean      | 0.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4848     |
# |    fps              | 519      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 23388    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.29e-06 |
# |    n_updates        | 5596     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.6     |
# |    ep_rew_mean      | 0.65     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4852     |
# |    fps              | 520      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 23545    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.76e-06 |
# |    n_updates        | 5636     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.3     |
# |    ep_rew_mean      | 0.62     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4856     |
# |    fps              | 521      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 23744    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.73e-05 |
# |    n_updates        | 5685     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 0.61     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4860     |
# |    fps              | 521      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 23801    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.9e-05  |
# |    n_updates        | 5700     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.7     |
# |    ep_rew_mean      | 0.6      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4864     |
# |    fps              | 522      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 23957    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.49e-06 |
# |    n_updates        | 5739     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32       |
# |    ep_rew_mean      | 0.59     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4868     |
# |    fps              | 523      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 24110    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.45e-05 |
# |    n_updates        | 5777     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.2     |
# |    ep_rew_mean      | 0.56     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4872     |
# |    fps              | 523      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 24255    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.72e-06 |
# |    n_updates        | 5813     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.2     |
# |    ep_rew_mean      | 0.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4876     |
# |    fps              | 524      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 24485    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.04e-06 |
# |    n_updates        | 5871     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.6     |
# |    ep_rew_mean      | 0.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4880     |
# |    fps              | 525      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 24548    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.9e-06  |
# |    n_updates        | 5886     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.9     |
# |    ep_rew_mean      | 0.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4884     |
# |    fps              | 525      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 24604    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.7e-06  |
# |    n_updates        | 5900     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.3     |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4888     |
# |    fps              | 525      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 24671    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.14e-06 |
# |    n_updates        | 5917     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.8     |
# |    ep_rew_mean      | 0.46     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4892     |
# |    fps              | 527      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 24940    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.15e-07 |
# |    n_updates        | 5984     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.3     |
# |    ep_rew_mean      | 0.44     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4896     |
# |    fps              | 527      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 25153    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.02e-06 |
# |    n_updates        | 6038     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.3     |
# |    ep_rew_mean      | 0.43     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4900     |
# |    fps              | 528      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 25358    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.24e-07 |
# |    n_updates        | 6089     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.8     |
# |    ep_rew_mean      | 0.41     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4904     |
# |    fps              | 528      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 25465    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.33e-06 |
# |    n_updates        | 6116     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.4     |
# |    ep_rew_mean      | 0.39     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4908     |
# |    fps              | 530      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 25780    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.82e-05 |
# |    n_updates        | 6194     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44       |
# |    ep_rew_mean      | 0.37     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4912     |
# |    fps              | 530      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 25970    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000179 |
# |    n_updates        | 6242     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.2     |
# |    ep_rew_mean      | 0.34     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4916     |
# |    fps              | 532      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 26196    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000163 |
# |    n_updates        | 6298     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.3     |
# |    ep_rew_mean      | 0.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4920     |
# |    fps              | 532      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 26340    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.48e-05 |
# |    n_updates        | 6334     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42       |
# |    ep_rew_mean      | 0.32     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4924     |
# |    fps              | 533      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 26466    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.76e-05 |
# |    n_updates        | 6366     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.1     |
# |    ep_rew_mean      | 0.31     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4928     |
# |    fps              | 534      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 26711    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.71e-07 |
# |    n_updates        | 6427     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.6     |
# |    ep_rew_mean      | 0.28     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4932     |
# |    fps              | 535      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 26921    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.05e-07 |
# |    n_updates        | 6480     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 46       |
# |    ep_rew_mean      | 0.26     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4936     |
# |    fps              | 537      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 27193    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.7e-07  |
# |    n_updates        | 6548     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.7     |
# |    ep_rew_mean      | 0.26     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4940     |
# |    fps              | 536      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 27298    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.3e-07  |
# |    n_updates        | 6574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.1     |
# |    ep_rew_mean      | 0.25     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4944     |
# |    fps              | 536      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 27426    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.25e-07 |
# |    n_updates        | 6606     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.7     |
# |    ep_rew_mean      | 0.26     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4948     |
# |    fps              | 536      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 27661    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.52e-06 |
# |    n_updates        | 6665     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.5     |
# |    ep_rew_mean      | 0.27     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4952     |
# |    fps              | 535      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 27792    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.69e-07 |
# |    n_updates        | 6697     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.1     |
# |    ep_rew_mean      | 0.27     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4956     |
# |    fps              | 534      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 28055    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.67e-07 |
# |    n_updates        | 6763     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 45.8     |
# |    ep_rew_mean      | 0.25     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4960     |
# |    fps              | 533      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 28377    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.01e-07 |
# |    n_updates        | 6844     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47.1     |
# |    ep_rew_mean      | 0.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4964     |
# |    fps              | 532      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 28664    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.2e-06  |
# |    n_updates        | 6915     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47.7     |
# |    ep_rew_mean      | 0.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4968     |
# |    fps              | 533      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 28879    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.97e-07 |
# |    n_updates        | 6969     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49       |
# |    ep_rew_mean      | 0.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4972     |
# |    fps              | 533      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 29150    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.2e-07  |
# |    n_updates        | 7037     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.8     |
# |    ep_rew_mean      | 0.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4976     |
# |    fps              | 534      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 29368    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.2e-07  |
# |    n_updates        | 7091     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.6     |
# |    ep_rew_mean      | 0.23     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4980     |
# |    fps              | 534      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 29404    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.71e-06 |
# |    n_updates        | 7100     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50       |
# |    ep_rew_mean      | 0.21     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4984     |
# |    fps              | 534      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 29602    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.44e-06 |
# |    n_updates        | 7150     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.9     |
# |    ep_rew_mean      | 0.21     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4988     |
# |    fps              | 535      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 29756    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.15e-07 |
# |    n_updates        | 7188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49.5     |
# |    ep_rew_mean      | 0.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4992     |
# |    fps              | 535      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 29892    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.62e-07 |
# |    n_updates        | 7222     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.6     |
# |    ep_rew_mean      | 0.27     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4996     |
# |    fps              | 535      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 30017    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00107  |
# |    n_updates        | 7254     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47.9     |
# |    ep_rew_mean      | 0.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5000     |
# |    fps              | 536      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 30148    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00537  |
# |    n_updates        | 7286     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 46.9     |
# |    ep_rew_mean      | 0.27     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5004     |
# |    fps              | 536      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 30156    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00491  |
# |    n_updates        | 7288     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 45.3     |
# |    ep_rew_mean      | 0.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5008     |
# |    fps              | 536      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 30307    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000549 |
# |    n_updates        | 7326     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.6     |
# |    ep_rew_mean      | 0.32     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5012     |
# |    fps              | 536      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 30333    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000275 |
# |    n_updates        | 7333     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.6     |
# |    ep_rew_mean      | 0.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5016     |
# |    fps              | 536      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 30357    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000187 |
# |    n_updates        | 7339     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.4     |
# |    ep_rew_mean      | 0.38     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5020     |
# |    fps              | 536      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 30381    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000195 |
# |    n_updates        | 7345     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39.7     |
# |    ep_rew_mean      | 0.42     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5024     |
# |    fps              | 536      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 30439    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00334  |
# |    n_updates        | 7359     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.1     |
# |    ep_rew_mean      | 0.45     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5028     |
# |    fps              | 536      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 30519    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000272 |
# |    n_updates        | 7379     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.4     |
# |    ep_rew_mean      | 0.48     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5032     |
# |    fps              | 536      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 30559    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0006   |
# |    n_updates        | 7389     |
# ...
# |    time_elapsed     | 86       |
# |    total_timesteps  | 47824    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.48e-05 |
# |    n_updates        | 11705    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | 0.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5884     |
# |    fps              | 551      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 47998    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.28e-06 |
# |    n_updates        | 11749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.6     |
# |    ep_rew_mean      | 0.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5888     |
# |    fps              | 551      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 48119    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.5e-06  |
# |    n_updates        | 11779    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.9     |
# |    ep_rew_mean      | 0.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5892     |
# |    fps              | 551      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 48192    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.51e-05 |
# |    n_updates        | 11797    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 0.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5896     |
# |    fps              | 551      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 48242    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.37e-06 |
# |    n_updates        | 11810    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 0.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5900     |
# |    fps              | 551      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 48262    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000505 |
# |    n_updates        | 11815    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20       |
# |    ep_rew_mean      | 0.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5904     |
# |    fps              | 551      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 48290    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000813 |
# |    n_updates        | 11822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.2     |
# |    ep_rew_mean      | 0.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5908     |
# |    fps              | 551      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 48314    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.76e-06 |
# |    n_updates        | 11828    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | 0.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5912     |
# |    fps              | 551      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 48341    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.64e-07 |
# |    n_updates        | 11835    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 0.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5916     |
# |    fps              | 551      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 48365    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.08e-05 |
# |    n_updates        | 11841    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 0.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5920     |
# |    fps              | 551      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 48391    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000126 |
# |    n_updates        | 11847    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 0.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5924     |
# |    fps              | 551      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 48416    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.53e-06 |
# |    n_updates        | 11853    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 0.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5928     |
# |    fps              | 551      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 48534    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000122 |
# |    n_updates        | 11883    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5932     |
# |    fps              | 552      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 48602    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.62e-06 |
# |    n_updates        | 11900    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5936     |
# |    fps              | 552      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 48626    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000491 |
# |    n_updates        | 11906    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5940     |
# |    fps              | 552      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 48745    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.64e-06 |
# |    n_updates        | 11936    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | 0.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5944     |
# |    fps              | 552      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 48901    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.54e-06 |
# |    n_updates        | 11975    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.8     |
# |    ep_rew_mean      | 0.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5948     |
# |    fps              | 552      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 49020    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00033  |
# |    n_updates        | 12004    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 0.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5952     |
# |    fps              | 552      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 49045    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.74e-06 |
# |    n_updates        | 12011    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 0.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5956     |
# |    fps              | 552      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 49069    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.63e-06 |
# |    n_updates        | 12017    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 0.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5960     |
# |    fps              | 553      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 49094    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000298 |
# |    n_updates        | 12023    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | 0.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5964     |
# |    fps              | 553      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 49212    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.94e-06 |
# |    n_updates        | 12052    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | 0.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5968     |
# |    fps              | 553      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 49256    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38e-06 |
# |    n_updates        | 12063    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 0.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5972     |
# |    fps              | 553      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 49320    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000108 |
# |    n_updates        | 12079    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 0.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5976     |
# |    fps              | 553      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 49344    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000103 |
# |    n_updates        | 12085    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 0.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5980     |
# |    fps              | 553      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 49515    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.04e-05 |
# |    n_updates        | 12128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 0.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5984     |
# |    fps              | 553      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 49577    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.65e-06 |
# |    n_updates        | 12144    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 0.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5988     |
# |    fps              | 554      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 49694    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.08e-06 |
# |    n_updates        | 12173    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 0.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5992     |
# |    fps              | 554      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 49816    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.23e-07 |
# |    n_updates        | 12203    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 0.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5996     |
# |    fps              | 554      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 49843    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.53e-07 |
# |    n_updates        | 12210    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | 0.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6000     |
# |    fps              | 554      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 49899    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.79e-07 |
# |    n_updates        | 12224    |
# ----------------------------------

# %% [markdown]
# Env2 implementation. [ place for your code ]

# %%
# TODO's:
# Import env 2    env_2 = Frozen Lake
# Train env 2
# plot env2 total rewards on sepearate lines for each algorithm ={DQN and PPO}
# modify hyperparameters and plot reward curves

# %% [markdown]
# Write a wrapper for changing reward function and plot the changes. (Bonus)

# %%
# Bonus TODO's: Your wrapper for reward function

# %% [markdown]
# # **Task 2: Creating Custom Environment (45 points)**
# In this question, you are required to model **a custom 4*4 gridworld problem** as Markov Decision Processes (MDPs). You must define the following components:
#
# <img src="data:image/png;base64,..." width="400"/>
#
# - **State Space ($ S $)**: The set of all possible states the agent can be in.
# - **Action Space ($ A $)**: The set of all possible actions the agent can take.
# - **Reward Function ($ R $)**: The reward the agent receives for taking an action in a given state.
# - **Transition Probability ($ P $)**: The probability of transitioning to a new state given the current state and action. If the environment is deterministic, this can be omitted.
#
# After defining the MDP components, implement problem using the **Gymnasium standard API**. Then, test the environments using various reinforcement learning algorithms (e.g., Q-Learning, DQN, PPO) and evaluate their performance.

# %%
# TODO: Defineing your custom env
class YourAwesomeEnvironment(gym.Env):
    def __init__(self) -> None:
        super().__init__()
        self.action_space = ...
        self.observation_space = ...

    def step(
        self, action: Any
    ) -> tuple[Any, SupportsFloat, bool, bool, dict[str, Any]]:
        return super().step(action)

    def reset(
        self, *, seed: int | None = None, options: dict[str, Any] | None = None
    ) -> tuple[Any, dict[str, Any]]:
        return super().reset(seed=seed, options=options)

    #Optional
    def render(self):
        return super().render()

    def close(self):
        return super().close()

# %%
# TODO: Training agent on your env

# %% [markdown]
# 📊 Algorithm Comparison
# Compare RL algorithms (e.g., PPO, DQN) based on:
# - Total reward over time
# - Sample efficiency
# - Hyperparameters

# %%
# TODO: Algorithm comparison code

# %% [markdown]
# # **Task 3: Pygame 🎮 Tutorial & Custom RL Environment (Bonus)**
#
# In this bonus task, you will implement a custom RL environment using Pygame and make it Gym-compatible for training an RL agent. Pygame is widely used for 2D game development and can be an excellent tool for creating custom RL environments. You will start by learning basic Pygame concepts (game loop, rendering, input handling), then implement a simple grid-based environment where an agent moves toward a goal while avoiding obstacles. Finally, you will train an RL agent using Stable-Baselines3 (SB3) to solve the environment. If you’re looking for inspiration, consider recreating the Chrome Dino game 🦖 as an RL environment which will be introduced at workshop or future TA sessions, but feel free to explore your own ideas!

# %% [markdown]
# ![preview.png](data:image/png;base64,...)
